# %% [markdown]
# # Mining the social web
# ## Workout 2. Understanding XML
#
# - CityU COM5507 201819A - Unit 2: Web data collection
# - 24 Oct 2018, Week 8: Mining the social web - data formats
#
#
# - Course Instructor: [Dr. Xinzhi Zhang](www.drxinzhizhang.com)  (JOUR, Hong Kong Baptist University)
#   - xzzhang2@gmail.com
#
#
# - The codes in this notebook are modified from various sources. All codes are for educational purposes only and released under the CC1.0.

# %% [markdown]
# ## XML basic: structures & finding the elements

# %% [markdown]
# - tutorial: https://stackabuse.com/reading-and-writing-xml-files-in-python/
# - official tutorial: https://docs.python.org/3.7/library/xml.etree.elementtree.html

# %% [markdown]
# - ```Element.find()``` finds the first child with a particular tag, and Element.text accesses the element’s text content.
# - ```Element.get()``` accesses the element’s attributes.
#
#
# - ```Element.findall()``` finds only elements with a tag which are direct children of the current element.
# - ```Element.iter()``` creates a tree iterator with the current element as the root. The iterator iterates over this element and all elements below it, in document (depth first) order.

# %%
import xml.etree.ElementTree as ET # always import this when parsing XML

# %%
data = '''
<person>
  <name>Chuck</name>
  <phone type="intl">
     +1 734 303 4456
   </phone>
   <email hide="yes"/>
</person>
'''

# %%
tree = ET.fromstring(data)
print('Name:', tree.find('name').text)
# what happened if we print: print('Name:', tree.find('name'))? 
print('Phone:', tree.find('phone').text) 
# compare: print('Phone:', tree.find('phone').text.strip()) 
print('Attrib', tree.find('email').get('hide'))
# Out:
# Name: Chuck
# Phone:
#      +1 734 303 4456
#
# Attrib yes

# %%
input = '''
<stuff>
    <users>
        <user x="2">
            <id>001</id>
            <name>Chuck</name>
        </user>
        <user x="7">
            <id>009</id>
            <name>Brent</name>
        </user>
    </users>
</stuff>'''

# %%
stuff = ET.fromstring(input)
lst = stuff.findall('users/user')
print(type(lst))
print('User count:', len(lst))
# Out:
# <class 'list'>
# User count: 2

# %%
for item in lst:
    print('Name', item.find('name').text)
    print('Id', item.find('id').text)
    print('Attribute', item.get("x"))
# Out:
# Name Chuck
# Id 001
# Attribute 2
# Name Brent
# Id 009
# Attribute 7

# %% [markdown]
# ## Another example: an official tutorial

# %%
country_data_as_string = '''
<data>
    <country name="Liechtenstein">
        <rank>1</rank>
        <year>2008</year>
        <gdppc>141100</gdppc>
        <neighbor name="Austria" direction="E"/>
        <neighbor name="Switzerland" direction="W"/>
    </country>
    <country name="Singapore">
        <rank>4</rank>
        <year>2011</year>
        <gdppc>59900</gdppc>
        <neighbor name="Malaysia" direction="N"/>
    </country>
    <country name="Panama">
        <rank>68</rank>
        <year>2011</year>
        <gdppc>13600</gdppc>
        <neighbor name="Costa Rica" direction="W"/>
        <neighbor name="Colombia" direction="E"/>
    </country>
</data>'''

# %%
import xml.etree.ElementTree as ET
tree = ET.parse('data.xml')
root = tree.getroot()

#root = ET.fromstring(country_data_as_string)

# %%
for child in root:
    print(child.tag, child.attrib)
# Out:
# country {'name': 'Liechtenstein'}
# country {'name': 'Singapore'}
# country {'name': 'Panama'}

# %%
# XML can be as paths 
root[0][1].text
# Out:
# '2008'

# %%
for neighbor in root.iter('neighbor'):
    print(neighbor.attrib)
# Out:
# {'name': 'Austria', 'direction': 'E'}
# {'name': 'Switzerland', 'direction': 'W'}
# {'name': 'Malaysia', 'direction': 'N'}
# {'name': 'Costa Rica', 'direction': 'W'}
# {'name': 'Colombia', 'direction': 'E'}

# %%
names = []
directions = []
for neighbor in root.iter('neighbor'):
    name = neighbor.get('name')
    direction = neighbor.get('direction') 
    #print(name, vote)
    names.append(name)
    directions.append(direction)

print(names)
print(directions)
# Out:
# ['Austria', 'Switzerland', 'Malaysia', 'Costa Rica', 'Colombia']
# ['E', 'W', 'N', 'W', 'E']

# %% [markdown]
# ## A real example: the Hong Kong LegCo voting
# - Open data: https://www.legco.gov.hk/general/chinese/open-legco/cm-201819.html#n1a
# - Data source: https://www.legco.gov.hk/yr18-19/chinese/counmtg/voting/cm_vote_20181010.xml
# - The Hong Kong LegCo voting record documented on the LegCo website is a very good example of open data, as well as a good practicum field for data analytical skills.

# %%
import xml.etree.ElementTree as ET  
tree = ET.parse('cm_vote_20181010.xml')  
root = tree.getroot()

# %%
root.tag
# Out:
# 'legcohk-vote'

# %%
root.attrib
# Out:
# {'{http://www.w3.org/2001/XMLSchema-instance}noNamespaceSchemaLocation': '/schema/legcohk-vote-schema.xsd'}

# %%
for child in root:
    print(child.tag, child.attrib)
# Out:
# meeting {'start-date': '10/10/2018', 'type': 'Council Meeting'}

# %%
for member in root.iter('member'):
    print(member.attrib)
# Out:
# {'name-ch': '梁君彥', 'name-en': 'Andrew LEUNG', 'constituency': 'Functional'}
# {'name-ch': '涂謹申', 'name-en': 'James TO', 'constituency': 'Functional'}
# {'name-ch': '梁耀忠', 'name-en': 'LEUNG Yiu-chung', 'constituency': 'Functional'}
# {'name-ch': '石禮謙', 'name-en': 'Abraham SHEK', 'constituency': 'Functional'}
# {'name-ch': '張宇人', 'name-en': 'Tommy CHEUNG', 'constituency': 'Functional'}
# {'name-ch': '李國麟', 'name-en': 'Prof Joseph LEE', 'constituency': 'Functional'}
# {'name-ch': '林健鋒', 'name-en': 'Jeffrey LAM', 'constituency': 'Functional'}
# {'name-ch': '黃定光', 'name-en': 'WONG Ting-kwong', 'constituency': 'Functional'}
# {'name-ch': '李慧琼', 'name-en': 'Starry LEE', 'constituency': 'Functional'}
# {'name-ch': '陳克勤', 'name-en': 'CHAN Hak-kan', 'constituency': 'Geographical'}
# {'name-ch': '陳健波', 'name-en': 'CHAN Kin-por', 'constituency': 'Functional'}
# {'name-ch': '梁美芬', 'name-en': 'Dr Priscilla LEUNG', 'constituency': 'Geographical'}
# {'name-ch': '黃國健', 'name-en': 'WONG Kwok-kin', 'constituency': 'Geographical'}
# {'name-ch': '葉劉淑儀', 'name-en': 'Mrs Regina IP', 'constituency': 'Geographical'}
# {'name-ch': '謝偉俊', 'name-en': 'Paul TSE', 'constituency': 'Geographical'}
# {'name-ch': '毛孟靜', 'name-en': 'Claudia MO', 'constituency': 'Geographical'}
# {'name-ch': '田北辰', 'name-en': 'Michael TIEN', 'constituency': 'Geographical'}
# {'name-ch': '何俊賢', 'name-en': 'Steven HO', 'constituency': 'Functional'}
# {'name-ch': '易志明', 'name-en': 'Frankie YICK', 'constituency': 'Functional'}
# {'name-ch': '胡志偉', 'name-en': 'WU Chi-wai', 'constituency': 'Geographical'}
# {'name-ch': '姚思榮', 'name-en': 'YIU Si-wing', 'constituency': 'Functional'}
# {'name-ch': '馬逢國', 'name-en': 'MA Fung-kwok', 'constituency': 'Functional'}
# {'name-ch': '莫乃光', 'name-en': 'Charles Peter MOK', 'constituency': 'Functional'}
# {'name-ch': '陳志全', 'name-en': 'CHAN Chi-chuen', 'constituency': 'Geographical'}
# {'name-ch': '陳恒鑌', 'name-en': 'CHAN Han-pan', 'constituency': 'Geographical'}
# {'name-ch': '梁志祥', 'name-en': 'LEUNG Che-cheung', 'constituency': 'Geographical'}
# {'name-ch': '梁繼昌', 'name-en': 'Kenneth LEUNG', 'constituency': 'Functional'}
# {'name-ch': '麥美娟', 'name-en': 'Alice MAK', 'constituency': 'Geographical'}
# {'name-ch': '郭家麒', 'name-en': 'Dr KWOK Ka-ki', 'constituency': 'Geographical'}
# {'name-ch': '郭偉强', 'name-en': 'KWOK Wai-keung', 'constituency': 'Geographical'}
# {'name-ch': '郭榮鏗', 'name-en': 'Dennis KWOK', 'constituency': 'Functional'}
# {'name-ch': '張華峰', 'name-en': 'Christopher CHEUNG', 'constituency': 'Functional'}
# {'name-ch': '張超雄', 'name-en': 'Dr Fernando CHEUNG', 'constituency': 'Geographical'}
# {'name-ch': '黃碧雲', 'name-en': 'Dr Helena WONG', 'constituency': 'Geographical'}
# {'name-ch': '葉建源', 'name-en': 'IP Kin-yuen', 'constituency': 'Functional'}
# {'name-ch': '葛珮帆', 'name-en': 'Dr Elizabeth QUAT', 'constituency': 'Geographical'}
# {'name-ch': '廖長江', 'name-en': 'Martin LIAO', 'constituency': 'Functional'}
# {'name-ch': '潘兆平', 'name-en': 'POON Siu-ping', 'constituency': 'Functional'}
# {'name-ch': '蔣麗芸', 'name-en': 'Dr CHIANG Lai-wan', 'constituency': 'Geographical'}
# {'name-ch': '盧偉國', 'name-en': 'Ir Dr LO Wai-kwok', 'constituency': 'Functional'}
# {'name-ch': '鍾國斌', 'name-en': 'CHUNG Kwok-pan', 'constituency': 'Functional'}
# {'name-ch': '楊岳橋', 'name-en': 'Alvin YEUNG', 'constituency': 'Geographical'}
# {'name-ch': '尹兆堅', 'name-en': 'Andrew WAN', 'constituency': 'Geographical'}
# {'name-ch': '朱凱廸', 'name-en': 'CHU Hoi-dick', 'constituency': 'Geographical'}
# {'name-ch': '吳永嘉', 'name-en': 'Jimmy NG', 'constituency': 'Functional'}
# {'name-ch': '何君堯', 'name-en': 'Dr Junius HO', 'constituency': 'Geographical'}
# {'name-ch': '何啟明', 'name-en': 'HO Kai-ming', 'constituency': 'Functional'}
# {'name-ch': '林卓廷', 'name-en': 'LAM Cheuk-ting', 'constituency': 'Geographical'}
# {'name-ch': '周浩鼎', 'name-en': 'Holden CHOW', 'constituency': 'Functional'}
# {'name-ch': '邵家輝', 'name-en': 'SHIU Ka-fai', 'constituency': 'Functional'}
# {'name-ch': '邵家臻', 'name-en': 'SHIU Ka-chun', 'constituency': 'Functional'}
# {'name-ch': '柯創盛', 'name-en': 'Wilson OR', 'constituency': 'Geographical'}
# {'name-ch': '容海恩', 'name-en': 'YUNG Hoi-yan', 'constituency': 'Geographical'}
# {'name-ch': '陳沛然', 'name-en': 'Dr Pierre CHAN', 'constituency': 'Functional'}
# {'name-ch': '陳振英', 'name-en': 'CHAN Chun-ying', 'constituency': 'Functional'}
# {'name-ch': '陳淑莊', 'name-en': 'Tanya CHAN', 'constituency': 'Geographical'}
# {'name-ch': '張國鈞', 'name-en': 'CHEUNG Kwok-kwan', 'constituency': 'Geographical'}
# {'name-ch': '許智峯', 'name-en': 'HUI Chi-fung', 'constituency': 'Geographical'}
# {'name-ch': '陸頌雄', 'name-en': 'LUK Chung-hung', 'constituency': 'Functional'}
# {'name-ch': '劉國勳', 'name-en': 'LAU Kwok-fan', 'constituency': 'Functional'}
# {'name-ch': '劉業強', 'name-en': 'Kenneth LAU', 'constituency': 'Functional'}
# {'name-ch': '鄭松泰', 'name-en': 'Dr CHENG Chung-tai', 'constituency': 'Geographical'}
# {'name-ch': '鄺俊宇', 'name-en': 'KWONG Chun-yu', 'constituency': 'Functional'}
# {'name-ch': '譚文豪', 'name-en': 'Jeremy TAM', 'constituency': 'Geographical'}
# {'name-ch': '范國威', 'name-en': 'Gary FAN', 'constituency': 'Geographical'}
# {'name-ch': '區諾軒', 'name-en': 'AU Nok-hin', 'constituency': 'Geographical'}
# {'name-ch': '鄭泳舜', 'name-en': 'Vincent CHENG', 'constituency': 'Geographical'}
# {'name-ch': '謝偉銓', 'name-en': 'Tony TSE', 'constituency': 'Functional'}

# %%
names = []
votes = []
for member in root.iter('member'):
    vote = member.find('vote').text
    name = member.get('name-ch') 
    #print(name, vote)
    votes.append(vote)
    names.append(name)

# %%
import pandas as pd

# %%
df_vote = {
    'names': names,
    'votes': votes
}

# %%
pd_vote = pd.DataFrame.from_dict(df_vote) 
print(pd_vote.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 2 columns):
# names    68 non-null object
# votes    68 non-null object
# dtypes: object(2)
# memory usage: 1.1+ KB
# None

# %%
pd_vote
# Out:
#    names    votes
# 0    梁君彥  Present
# 1    涂謹申      Yes
# 2    梁耀忠      Yes
# 3    石禮謙       No
# 4    張宇人       No
# 5    李國麟   Absent
# 6    林健鋒       No
# 7    黃定光   Absent
# 8    李慧琼   Absent
# 9    陳克勤      Yes
# 10   陳健波       No
# 11   梁美芬   Absent
# 12   黃國健  Present
# 13  葉劉淑儀       No
# 14   謝偉俊   Absent
# 15   毛孟靜   Absent
# 16   田北辰       No
# 17   何俊賢  Abstain
# 18   易志明       No
# 19   胡志偉      Yes
# 20   姚思榮       No
# 21   馬逢國       No
# 22   莫乃光   Absent
# 23   陳志全   Absent
# 24   陳恒鑌      Yes
# 25   梁志祥      Yes
# 26   梁繼昌   Absent
# 27   麥美娟  Abstain
# 28   郭家麒      Yes
# 29   郭偉强  Abstain
# ..   ...      ...
# 38   蔣麗芸      Yes
# 39   盧偉國       No
# 40   鍾國斌       No
# 41   楊岳橋      Yes
# 42   尹兆堅      Yes
# 43   朱凱廸   Absent
# 44   吳永嘉       No
# 45   何君堯       No
# 46   何啟明  Abstain
# 47   林卓廷      Yes
# 48   周浩鼎      Yes
# 49   邵家輝       No
# 50   邵家臻   Absent
# 51   柯創盛      Yes
# 52   容海恩       No
# 53   陳沛然      Yes
# 54   陳振英       No
# 55   陳淑莊      Yes
# 56   張國鈞   Absent
# 57   許智峯      Yes
# 58   陸頌雄  Abstain
# 59   劉國勳   Absent
# 60   劉業強   Absent
# 61   鄭松泰      Yes
# 62   鄺俊宇      Yes
# 63   譚文豪      Yes
# 64   范國威      Yes
# 65   區諾軒   Absent
# 66   鄭泳舜      Yes
# 67   謝偉銓       No
#
# [68 rows x 2 columns]

# %%
pd_vote
# Out:
#    names    votes
# 0    梁君彥  Present
# 1    涂謹申      Yes
# 2    梁耀忠      Yes
# 3    石禮謙       No
# 4    張宇人       No
# 5    李國麟   Absent
# 6    林健鋒       No
# 7    黃定光   Absent
# 8    李慧琼   Absent
# 9    陳克勤      Yes
# 10   陳健波       No
# 11   梁美芬   Absent
# 12   黃國健  Present
# 13  葉劉淑儀       No
# 14   謝偉俊   Absent
# 15   毛孟靜   Absent
# 16   田北辰       No
# 17   何俊賢  Abstain
# 18   易志明       No
# 19   胡志偉      Yes
# 20   姚思榮       No
# 21   馬逢國       No
# 22   莫乃光   Absent
# 23   陳志全   Absent
# 24   陳恒鑌      Yes
# 25   梁志祥      Yes
# 26   梁繼昌   Absent
# 27   麥美娟  Abstain
# 28   郭家麒      Yes
# 29   郭偉强  Abstain
# ..   ...      ...
# 38   蔣麗芸      Yes
# 39   盧偉國       No
# 40   鍾國斌       No
# 41   楊岳橋      Yes
# 42   尹兆堅      Yes
# 43   朱凱廸   Absent
# 44   吳永嘉       No
# 45   何君堯       No
# 46   何啟明  Abstain
# 47   林卓廷      Yes
# 48   周浩鼎      Yes
# 49   邵家輝       No
# 50   邵家臻   Absent
# 51   柯創盛      Yes
# 52   容海恩       No
# 53   陳沛然      Yes
# 54   陳振英       No
# 55   陳淑莊      Yes
# 56   張國鈞   Absent
# 57   許智峯      Yes
# 58   陸頌雄  Abstain
# 59   劉國勳   Absent
# 60   劉業強   Absent
# 61   鄭松泰      Yes
# 62   鄺俊宇      Yes
# 63   譚文豪      Yes
# 64   范國威      Yes
# 65   區諾軒   Absent
# 66   鄭泳舜      Yes
# 67   謝偉銓       No
#
# [68 rows x 2 columns]

# %% [markdown]
# ## Challenges:
# 1. Try to use Pandas package to examine  this voting record and explore further about the patterns of voting, if any.
